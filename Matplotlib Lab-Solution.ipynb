# %% [markdown]
# # Matplotlib Lab

# %%
import numpy as np
import pylab as plt
# %matplotlib inline

# %% [markdown]
# Create a numpy array with 100 numbers from 1 to 20. You are not allowed to use any loop

# %%
b=np.linspace(1,20,100)

# %% [markdown]
# Create a numpy array containing the sine of the numbers from the above array.

# %%
c=np.sin(b)

# %% [markdown]
# Create a graph with the last 2 arrays

# %%
plt.plot(b,c)

# %% [raw]
# Create a function:
#
#     def plot(fn,a,b,num_points)
#
# Shows the plot of function fn between a and b using num_points

# %%
def plot(f,a,b,num_points):
    x = np.linspace(a,b,num_points)
    y = f(x)
    pylab.plot(x,y)

# %% [raw]
# Use it for the function f(x) = x ∗ cos( 1/x ) in the range:
#     1.	[0 ,pi/4]
#     2.	[-10,10]
#     3.  [0,2]

# %%
def my_function(x):
    my_result = x*np.cos(1/x)
    return my_result


plot(my_function,0.001,np.pi/4,1000)

# %%
plot(my_function,-10,10,100)

# %%
plot(my_function,0.01,2,100)

# %% [markdown]
# Create a text file with 2 lines of numbers:
#
# 23 34 45 35 60 40 56 58<br>
# 2 5 6 8 12 15 18 25

# %% [markdown]
# load the file into numpy array

# %%
x=np.loadtxt('data2.txt')

# %%
x
# Out:
# array([[23., 34., 45., 35., 60., 40., 56., 58.],
#        [ 2.,  5.,  6.,  8., 12., 15., 18., 25.]])

# %% [markdown]
# Create a solid line graph from the above data (first line is y)

# %%
plt.plot(x[1],x[0])

# %% [markdown]
# Change the graph to green solid line with square markers

# %%
plt.plot(x[1],x[0],'g-s')

# %% [markdown]
# Change the graph to pie graph(use only the first line)

# %%
p,s=plt.pie(x[1])

# %% [markdown]
# Add a legend to the pie chart

# %%
lb=['Q1-17','Q2-17','Q3-17','Q4-17','Q1-18','Q2-18','Q3-18','Q4-18']
p,s=plt.pie(x[1],labels=lb)
#plt.legend(p,lb)
