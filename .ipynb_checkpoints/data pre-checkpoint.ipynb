# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %%
df = pd.read_csv("pupils1.csv")

# %%
df.head()
# Out:
#     Name Gender   City  Height  Weight  Avg Grades
# 0   dina      F  Haifa     110      26          64
# 1   adar      M    TLV     113      30          70
# 2  efrat      F    Aco     115      33          45
# 3  ester      F  Haifa     130      48          90
# 4    avi      M    Aco     143      58          89

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
# Name          9 non-null object
# Gender        9 non-null object
# City          9 non-null object
# Height        9 non-null int64
# Weight        9 non-null int64
# Avg Grades    9 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 512.0+ bytes

# %%
df.describe()
# Out:
#            Height     Weight  Avg Grades
# count    9.000000   9.000000    9.000000
# mean   139.222222  51.444444   71.000000
# std     22.998792  17.791228   16.484842
# min    110.000000  26.000000   45.000000
# 25%    115.000000  33.000000   60.000000
# 50%    143.000000  58.000000   70.000000
# 75%    155.000000  66.000000   89.000000
# max    172.000000  71.000000   90.000000

# %%
df.corr()
# Out:
#               Height    Weight  Avg Grades
# Height      1.000000  0.982494    0.202436
# Weight      0.982494  1.000000    0.291525
# Avg Grades  0.202436  0.291525    1.000000

# %%
sn.heatmap(df.corr(),annot=True)

# %%
pd.Categorical(df['City'])
# Out:
# [Haifa, TLV, Aco, Haifa, Aco, Haifa, TLV, TLV, Haifa]
# Categories (3, object): [Aco, Haifa, TLV]

# %%
df['Citycode'] =pd.Categorical(df['City']).codes

# %%
df.drop(['Name','City'],axis=1)
# Out:
#   Gender  Height  Weight  Avg Grades  Citycode
# 0      F     110      26          64         1
# 1      M     113      30          70         2
# 2      F     115      33          45         0
# 3      F     130      48          90         1
# 4      M     143      58          89         0
# 5      M     155      61          76         1
# 6      M     155      66          55         2
# 7      M     160      70          90         2
# 8      F     172      71          60         1

# %%
df
# Out:
#     Name Gender   City  Height  Weight  Avg Grades  Citycode
# 0   dina      F  Haifa     110      26          64         1
# 1   adar      M    TLV     113      30          70         2
# 2  efrat      F    Aco     115      33          45         0
# 3  ester      F  Haifa     130      48          90         1
# 4    avi      M    Aco     143      58          89         0
# 5    eli      M  Haifa     155      61          76         1
# 6   ehud      M    TLV     155      66          55         2
# 7   dani      M    TLV     160      70          90         2
# 8   agam      F  Haifa     172      71          60         1

# %%
df2 = pd.get_dummies(df['City'])

# %%
df2
# Out:
#    Aco  Haifa  TLV
# 0    0      1    0
# 1    0      0    1
# 2    1      0    0
# 3    0      1    0
# 4    1      0    0
# 5    0      1    0
# 6    0      0    1
# 7    0      0    1
# 8    0      1    0

# %%
pd.concat([df,df2],axis=1)
# Out:
#     Name Gender   City  Height  Weight  Avg Grades  Citycode  Aco  Haifa  TLV
# 0   dina      F  Haifa     110      26          64         1    0      1    0
# 1   adar      M    TLV     113      30          70         2    0      0    1
# 2  efrat      F    Aco     115      33          45         0    1      0    0
# 3  ester      F  Haifa     130      48          90         1    0      1    0
# 4    avi      M    Aco     143      58          89         0    1      0    0
# 5    eli      M  Haifa     155      61          76         1    0      1    0
# 6   ehud      M    TLV     155      66          55         2    0      0    1
# 7   dani      M    TLV     160      70          90         2    0      0    1
# 8   agam      F  Haifa     172      71          60         1    0      1    0

# %%
df3 = pd.get_dummies(df['Gender'],drop_first=True)

# %%
df3
# Out:
#    M
# 0  0
# 1  1
# 2  0
# 3  0
# 4  1
# 5  1
# 6  1
# 7  1
# 8  0

# %%
dfres = pd.concat([df,df2,df3],axis=1)

# %%
dfres.head()
# Out:
#     Name Gender   City  Height  Weight  Avg Grades  Citycode  Aco  Haifa  TLV  \
# 0   dina      F  Haifa     110      26          64         1    0      1    0
# 1   adar      M    TLV     113      30          70         2    0      0    1
# 2  efrat      F    Aco     115      33          45         0    1      0    0
# 3  ester      F  Haifa     130      48          90         1    0      1    0
# 4    avi      M    Aco     143      58          89         0    1      0    0
#
#    M
# 0  0
# 1  1
# 2  0
# 3  0
# 4  1

# %%
dfres.drop(['Name','Gender','City','Citycode'],inplace=True,axis=1)

# %%
dfres
# Out:
#    Height  Weight  Avg Grades  Aco  Haifa  TLV  M
# 0     110      26          64    0      1    0  0
# 1     113      30          70    0      0    1  1
# 2     115      33          45    1      0    0  0
# 3     130      48          90    0      1    0  0
# 4     143      58          89    1      0    0  1
# 5     155      61          76    0      1    0  1
# 6     155      66          55    0      0    1  1
# 7     160      70          90    0      0    1  1
# 8     172      71          60    0      1    0  0

# %%
dfres.as_matrix()
# Out:
# array([[110,  26,  64,   0,   1,   0,   0],
#        [113,  30,  70,   0,   0,   1,   1],
#        [115,  33,  45,   1,   0,   0,   0],
#        [130,  48,  90,   0,   1,   0,   0],
#        [143,  58,  89,   1,   0,   0,   1],
#        [155,  61,  76,   0,   1,   0,   1],
#        [155,  66,  55,   0,   0,   1,   1],
#        [160,  70,  90,   0,   0,   1,   1],
#        [172,  71,  60,   0,   1,   0,   0]], dtype=int64)
